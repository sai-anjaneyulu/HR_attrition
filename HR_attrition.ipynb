# %%
#Importing the pandas library
import pandas as pd

# %%
#Pandas Library reading the CSV file
df = pd.read_csv(r'C:\Users\sai venkat\Downloads\HR_Employee_attrition_Data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               3
# 3                 3          4  Life Sciences              1               4
# 4                 2          1        Medical              1               5
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().any()   #checking Null values if any
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
Attrition = pd.get_dummies(df['Attrition'],drop_first=True)
#Getting dummies for column attrition which is dependent Variable

# %%
df = pd.concat([df,Attrition],axis=1)
df.head()                              #Concating the column attrtion to original data which is now YES column
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               3
# 3                 3          4  Life Sciences              1               4
# 4                 2          1        Medical              1               5
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df = df.drop(['Attrition'],axis=1)  #Again droping the Attrition culumn
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               3
# 3                 3          4  Life Sciences              1               4
# 4                 2          1        Medical              1               5
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        2  ...            80                 0
# ...

# %%
df.BusinessTravel.value_counts()  #Counting the values
# Out:
# Travel_Rarely        2086
# Travel_Frequently     554
# Non-Travel            300
# Name: BusinessTravel, dtype: int64

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'BusinessTravel'. 
df['BusinessTravel']= label_encoder.fit_transform(df['BusinessTravel']) 
  
df['BusinessTravel'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0   41               2       1102                   Sales                 1
# 1   49               1        279  Research & Development                 8
# 2   37               2       1373  Research & Development                 2
# 3   33               1       1392  Research & Development                 3
# 4   27               2        591  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               3
# 3          4  Life Sciences              1               4
# 4          1        Medical              1               5
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        2  ...            80                 0
# ...

# %%
df.Department.unique() #Staing the unique values in Department Column
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Department'. 
df['Department']= label_encoder.fit_transform(df['Department']) 
  
df['Department'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#   EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0  Life Sciences              1               1                        2  ...
# 1  Life Sciences              1               2                        3  ...
# 2          Other              1               3                        4  ...
# 3  Life Sciences              1               4                        4  ...
# 4        Medical              1               5                        1  ...
#
# ...

# %%
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Educationalfield'. 
df['EducationField']= label_encoder.fit_transform(df['EducationField']) 
  
df['EducationField'].unique()
# Out:
# array([1, 4, 3, 2, 5, 0], dtype=int64)

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               3                        4
# 3               1              1               4                        4
# 4               3              1               5                        1
#
#    ... StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Gender'. 
df['Gender']= label_encoder.fit_transform(df['Gender']) 
  
df['Gender'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               3                        4
# 3               1              1               4                        4
# 4               3              1               5                        1
#
#    ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# BusinessTravel               int32
# DailyRate                    int64
# Department                   int32
# DistanceFromHome             int64
# Education                    int64
# EducationField               int32
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int32
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# ...

# %%
df.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Jobrole'. 
df['JobRole']= label_encoder.fit_transform(df['JobRole']) 
  
df['JobRole'].unique()
# Out:
# array([7, 6, 2, 4, 0, 3, 8, 5, 1], dtype=int64)

# %%
df.dtypes #as you can see still there is object in my maritalstatus,over18,Overtime
# Out:
# Age                          int64
# BusinessTravel               int32
# DailyRate                    int64
# Department                   int32
# DistanceFromHome             int64
# Education                    int64
# EducationField               int32
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int32
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int32
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# ...

# %%
df.MaritalStatus.unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'Maritalstatus'. 
df['MaritalStatus']= label_encoder.fit_transform(df['MaritalStatus']) 
  
df['MaritalStatus'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df.Over18.unique() #all values are in the form of array 'y'
# Out:
# array(['Y'], dtype=object)

# %%
df = df.drop(['Over18'],axis=1)#droping the Over18 column 
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               3                        4
# 3               1              1               4                        4
# 4               3              1               5                        1
#
#    ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.OverTime .unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'OverTime'. 
df['OverTime']= label_encoder.fit_transform(df['OverTime']) 
  
df['OverTime'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.dtypes #types of data
# Out:
# Age                         int64
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# ...

# %%
df.isnull().any()  #checking null values
# Out:
# Age                         False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# StockOptionLevel            False
# TotalWorkingYears           False
# ...

# %%
df.corr() #correlation check
# Out:
#                                Age  BusinessTravel  DailyRate  Department  \
# Age                       1.000000        0.024751   0.010661   -0.031882
# BusinessTravel            0.024751        1.000000  -0.004086   -0.009044
# DailyRate                 0.010661       -0.004086   1.000000    0.007109
# Department               -0.031882       -0.009044   0.007109    1.000000
# DistanceFromHome         -0.001686       -0.024469  -0.004985    0.017225
# Education                 0.208034        0.000757  -0.016806    0.007996
# EducationField           -0.040873        0.023724   0.037709    0.013720
# EmployeeCount                  NaN             NaN        NaN         NaN
# EmployeeNumber           -0.005175       -0.007905  -0.025742   -0.005183
# EnvironmentSatisfaction   0.010146        0.004174   0.018355   -0.019395
# Gender                   -0.036311       -0.032981  -0.011716   -0.041583
# HourlyRate                0.024287        0.026528   0.023381   -0.004144
# ...

# %%
import seaborn as sns #importing seaborn library for visualization

# %%
sns.heatmap(df.corr())

# %%
df.describe() #desrciptive statistics of data
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  2940.000000     2940.000000  2940.000000  2940.000000
# mean     36.923810        1.607483   802.485714     1.260544
# std       9.133819        0.665342   403.440447     0.527703
# min      18.000000        0.000000   102.000000     0.000000
# 25%      30.000000        1.000000   465.000000     1.000000
# 50%      36.000000        2.000000   802.000000     1.000000
# 75%      43.000000        2.000000  1157.000000     2.000000
# max      60.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       2940.000000  2940.000000     2940.000000         2940.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.105485     1.023991        1.331143            0.0
# min            1.000000     1.000000        0.000000            1.0
# 25%            2.000000     2.000000        1.000000            1.0
# ...

# %%
X = df.drop(['Yes'],axis=1)
y = df[['Yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
clf_random_forest = RandomForestClassifier(n_estimators=100)
clf_random_forest.fit(X_train,y_train)
y_pred = clf_random_forest.predict(X_test)
# Out:
# C:\anacondapy\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9523809523809523

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       503
#            1       0.77      0.95      0.85        85
#
#    micro avg       0.95      0.95      0.95       588
#    macro avg       0.88      0.95      0.91       588
# weighted avg       0.96      0.95      0.95       588
